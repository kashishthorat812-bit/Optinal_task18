# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishthorat812-bit/Optinal_task18/blob/main/optional_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-8d1a3cb5-e5f8-4a0b-b3ad-f2bcd252a5ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d1a3cb5-e5f8-4a0b-b3ad-f2bcd252a5ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Video_Game_Sales_Sample.csv")

# %%
df.head(10)
# Out:
#    Rank     Name  Platform      Genre   Publisher  Global_Sales_M
# 0     1   Game 1       PS4     Sports          EA            0.62
# 1     2   Game 2       PS5        RPG     Ubisoft            0.74
# 2     3   Game 3  Xbox One     Racing        Sony            0.86
# 3     4   Game 4    Switch  Adventure  Activision            0.98
# 4     5   Game 5        PC     Action    Nintendo            1.10
# 5     6   Game 6       PS4     Sports          EA            1.22
# 6     7   Game 7       PS5        RPG     Ubisoft            1.34
# 7     8   Game 8  Xbox One     Racing        Sony            1.46
# 8     9   Game 9    Switch  Adventure  Activision            1.58
# 9    10  Game 10        PC     Action    Nintendo            1.70

# %%
df.shape
# Out:
# (100, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            100 non-null    int64
#  1   Name            100 non-null    object
#  2   Platform        100 non-null    object
#  3   Genre           100 non-null    object
#  4   Publisher       100 non-null    object
#  5   Global_Sales_M  100 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#              Rank  Global_Sales_M
# count  100.000000      100.000000
# mean    50.500000        6.560000
# std     29.011492        3.481379
# min      1.000000        0.620000
# 25%     25.750000        3.590000
# 50%     50.500000        6.560000
# 75%     75.250000        9.530000
# max    100.000000       12.500000

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Genre             0
# Publisher         0
# Global_Sales_M    0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.histplot(x="Global_Sales_M",data=df)
plt.title("Distribution of global sales")
plt.xlabel("Global sales")
plt.ylabel("Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["Rank"],kde=True,bins=10)
plt.title("Distribution of Rank")
plt.xlabel("Rank")
plt.ylabel("Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("Average global sales :")
print(df["Global_Sales_M"].mean())
# Out:
# Average global sales :
# 6.56

# %%
print("Maximum global sales :")
print(df["Global_Sales_M"].max())
# Out:
# Maximum global sales :
# 12.5

# %%
print("Minimum global sales :")
print(df["Global_Sales_M"].min())
# Out:
# Minimum global sales :
# 0.62
